# %%
import numpy as np
import os
os.getcwd()
print("The current directory is: ")
print(os.getcwd())
path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)
print(os.getcwd())
# Out:
# The current directory is:
# c:\Users\nguye\Desktop\Crystal-Plasticity-COE-Project\parameter_analysis
# c:\Users\nguye\Desktop\Crystal-Plasticity-COE-Project

# %%
material = "RVE_1_40_D"
CPLaw = "PH"
data = np.load(f"parameter_analysis/{material}/{CPLaw}/results/analysis_processCurves.npy", allow_pickle=True).tolist()
print(data["linear_uniaxial_RD"]['gdot0'])
# Out:
# {'1.5e-3': {'strain': array([-1.14103355e-18, -1.13841228e-18, -1.02289603e-06,  8.99921979e-05,
#         4.49497390e-04,  8.81574094e-04,  1.33750639e-03,  1.80705827e-03,
#         2.28441314e-03,  2.76607576e-03,  3.25016261e-03,  9.74246746e-03,
#         1.62156791e-02,  2.26565717e-02,  2.90635812e-02,  3.54361365e-02,
#         4.17739497e-02,  4.80768289e-02,  5.43447055e-02,  6.05775786e-02,
#         6.67754960e-02,  7.29385496e-02,  7.90668723e-02,  8.51606319e-02,
#         9.12200170e-02,  9.72452255e-02,  1.03236461e-01,  1.09193940e-01,
#         1.15117890e-01,  1.21008553e-01,  1.26866177e-01,  1.32691017e-01,
#         1.38483337e-01,  1.44243405e-01,  1.49971491e-01,  1.55667868e-01,
#         1.61332819e-01,  1.66966631e-01,  1.72569599e-01,  1.78142017e-01,
#         1.83684180e-01]), 'stress': array([9.10260006e-14, 3.54249755e+01, 7.09257502e+01, 9.98980760e+01,
#        1.09900737e+02, 1.14883637e+02, 1.18239493e+02, 1.20647081e+02,
# ...
