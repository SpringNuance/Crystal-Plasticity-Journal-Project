# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML, Image

plt.rcParams['animation.writer'] = 'avconv'

# equivalent to rcParams['animation.html'] = 'html5'
rc('animation', html='html5')

# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots()

ax.set_xlim(( 0, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return (line,)

# call the animator. blit=True means only re-draw the parts that 
# have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
anim

#writergif = animation.PillowWriter(fps=30) 
#anim.save("./", writer=writergif)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:161, in MovieWriterRegistry.__getitem__(self, name)
#     160 try:
# --> 161     return self.avail[name]
#     162 except KeyError:
#
# KeyError: 'avconv'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1389, in Animation._repr_html_(self)
#    1387 fmt = rcParams['animation.html']
#    1388 if fmt == 'html5':
# -> 1389     return self.to_html5_video()
#    1390 elif fmt == 'jshtml':
#    1391     return self.to_jshtml()
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1326, in Animation.to_html5_video(self, embed_limit)
#    1323 path = Path(tmpdir, "temp.m4v")
#    1324 # We create a writer manually so that we can get the
#    1325 # appropriate size for the tag
# -> 1326 Writer = writers[rcParams['animation.writer']]
#    1327 writer = Writer(codec='h264',
#    1328                 bitrate=rcParams['animation.bitrate'],
#    1329                 fps=1000. / self._interval)
#    1330 self.save(str(path), writer=writer)
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:163, in MovieWriterRegistry.__getitem__(self, name)
#     161     return self.avail[name]
#     162 except KeyError:
# --> 163     raise RuntimeError(
#     164         'Requested MovieWriter ({}) not available'.format(name))
#
# RuntimeError: Requested MovieWriter (avconv) not available

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

plt.rcParams['animation.writer'] = 'avconv'

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_ylim([0,11])
ax.set_xlim([0,100])

u, v, ims = [], [], []
u.append(0)
v.append(10)
for i in range(100):
    u.append(i+1)
    v.append(10)
    ims.append(ax.plot(u, v, 'b-', linewidth=3.))

im_ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=3000,
    blit=True) 

im_ani.save('c.mp4')
# Out:
# MovieWriter avconv unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/PIL/Image.py:2082, in Image.save(self, fp, format, **params)
#    2081 try:
# -> 2082     format = EXTENSION[ext]
#    2083 except KeyError:
#
# KeyError: '.mp4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 23
#      18     ims.append(ax.plot(u, v, 'b-', linewidth=3.))
#      20 im_ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=3000,
#      21     blit=True)
# ---> 23 im_ani.save('c.mp4')
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:1156, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                     progress_callback(frame_number, total_frames)
#    1155                     frame_number += 1
# -> 1156             writer.grab_frame(**savefig_kwargs)
#    1158 # Reconnect signal for first draw if necessary
#    1159 if reconnect_first_draw:
#
# File /usr/lib/python3.8/contextlib.py:120, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     118 if type is None:
#     119     try:
# --> 120         next(self.gen)
#     121     except StopIteration:
#     122         return False
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:232, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     230     yield self
#     231 finally:
# --> 232     self.finish()
#
# File /usr/lib/python3/dist-packages/matplotlib/animation.py:575, in PillowWriter.finish(self)
#     574 def finish(self):
# --> 575     self._frames[0].save(
#     576         self._outfile, save_all=True, append_images=self._frames[1:],
#     577         duration=int(1000 / self.fps), loop=0)
#
# File /usr/lib/python3/dist-packages/PIL/Image.py:2084, in Image.save(self, fp, format, **params)
#    2082         format = EXTENSION[ext]
#    2083     except KeyError:
# -> 2084         raise ValueError("unknown file extension: {}".format(ext))
#    2086 if format.upper() not in SAVE:
#    2087     init()
#
# ValueError: unknown file extension: .mp4

# %%
"""
Matplotlib Animation Example

author: Jake Vanderplas
email: vanderplas@astro.washington.edu
website: http://jakevdp.github.com
license: BSD
Please feel free to use and modify this, but keep the above information. Thanks!
"""

import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('basic_animation.gif', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()
# Out:
# MovieWriter avconv unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
